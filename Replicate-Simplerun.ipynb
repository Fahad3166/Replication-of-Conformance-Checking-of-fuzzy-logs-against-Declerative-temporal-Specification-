# %%
import sys
sys.path.append('FLTLf')
from FLTLf.parser import LTLfParser
import time
import torch
import pandas as pd
import pdb
import os
from FLTLf.parser import LTLfParser
from FLTLf.converter import Converter
from FLTLf import core
import input
import traceback
import argparse

# Remove unrecognized arguments if running in Jupyter/IPython
if '__file__' not in globals():  # If not running as a standalone script
    sys.argv = sys.argv[:1]  # Retain only the script name

parser = argparse.ArgumentParser()
parser.add_argument('-d', "--device", default="cpu")

args = parser.parse_args()
core.device = args.device
core.debug = False

torch.manual_seed(0)

num_runs = 10
results = {"Run" : [], "Num. Cases" : [], "Case Length" : []}
batch_sizes_column = []
maxlengths_column = []
run_column = []

i = 0 
maxlengths = [i for i in range(500, 2500, 500)]
batch_sizes = [100, 1000, 10000,100000]
num_AP = 2
predicate_names = [f"p{i}" for i in range(num_AP)]

simple_formulas = ["(X(p0) >= 0.5)", "(WX(p0) >= 0.5)", "(G(p0) >= 0.5)", "(F(p0) >= 0.5)", "((p0Up1) >= 0.5)", "((p0Wp1) >= 0.5)", "((p0Rp1) >= 0.5)", "((p0Mp1) >= 0.5)"]

results_per_formula = {formula : [] for formula in simple_formulas}

#verbose printouts
verbose = False
#save results on a csv
savefile = True
#padding needed?
skippadding = True

#for every combination of maxlength, batchsize
for batch_size in batch_sizes:
    for maxlength in maxlengths:
        
        run_column.extend([i for i in range(num_runs)])
        batch_sizes_column.extend([batch_size]*num_runs)
        maxlengths_column.extend([maxlength]*num_runs)

        print("------times-------")
        start = time.time()

        # Generate a random tensor log
        tensor_log = torch.rand(batch_size, maxlength, len(predicate_names), dtype=torch.half)
        rand = time.time()
        print(f"RANDOM GEN time {rand - start}")

        # Padding
        converter = Converter(predicate_names)    
        tensor_log = converter.log2tensor(tensor_log, verbose, skippadding) 

        if not(skippadding):
            print(f"PADDING time {time.time() - rand}")
        else:
            print(f"PADDING skipped")        

        # Parsing into a formula
        parser = LTLfParser()
        
        # For each formula
        for formula in simple_formulas:
            start = time.time()
                
            # Slicing of predicates not in formula
            # The core routine reads the predicate_names from input, so we override them
            core.tensor_log, input.predicate_names = converter.slice_tensor_log(tensor_log, formula, verbose)
            core.tensor_log = core.tensor_log.to(core.device)
                
            # Setting dimensions for practical access
            core.batch_size = converter.batch_size
            core.maxlength = converter.maxlength

            ready = time.time()
            print(f"SLICING TIME {ready - start}")

            try:
                pyformula = parser(formula)     
            except Exception as e:
                print(traceback.format_exc())

            print(f"PARSING TIME {time.time() - ready}")
                            
            for run in range(num_runs):
                start = time.time()
                visitor = core.Visitor()

                print("------------------")
                print(f"Evaluation of {pyformula.print()} at instant {i} :")
                try:
                    visitor.visit(pyformula, i)
                except Exception as e:
                    print(traceback.format_exc())

                end = time.time()
                exec_time = end - start

                if savefile:
                    results_per_formula[formula].append(exec_time)

                print(f"({run}, {core.batch_size}, {core.maxlength}) -> {exec_time}")


results["Run"] = run_column
results["Num. Cases"] = batch_sizes_column
results["Case Length"] = maxlengths_column

results_df = pd.DataFrame.from_dict(results_per_formula)
settings_df = pd.DataFrame.from_dict(results)
results_df = pd.concat([settings_df, results_df], axis=1)

if savefile:
    os.makedirs('results', exist_ok=True)
    results_df.to_csv(os.path.join('results', f'simple_conformance_check_times_{core.device.upper()}.csv'))
    print("Results saved successfully.")
# Out:
# ------times-------
# RANDOM GEN time 0.0
# PADDING skipped
# SLICING TIME 0.0
# PARSING TIME 0.0
# ------------------
# Evaluation of NEXT((p0 >= 0.5)) at instant 0 :
#
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (6, 100, 500) -> 0.015624523162841797
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (7, 100, 500) -> 0.031252384185791016
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (8, 100, 500) -> 0.03641343116760254
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (9, 100, 500) -> 0.015633344650268555
# ------times-------
# RANDOM GEN time 0.01563286781311035
# PADDING skipped
# SLICING TIME 0.0
# PARSING TIME 0.0
# ------------------
# Evaluation of NEXT((p0 >= 0.5)) at instant 0 :
# (0, 100, 1000) -> 0.0
# ------------------
# Evaluation of NEXT((p0 >= 0.5)) at instant 0 :
# (1, 100, 1000) -> 0.0
# ------------------
# Evaluation of NEXT((p0 >= 0.5)) at instant 0 :
# (2, 100, 1000) -> 0.0
# ------------------
# Evaluation of NEXT((p0 >= 0.5)) at instant 0 :
# (3, 100, 1000) -> 0.0
# ------------------
# Evaluation of NEXT((p0 >= 0.5)) at instant 0 :
# (4, 100, 1000) -> 0.0
# ------------------
# Evaluation of NEXT((p0 >= 0.5)) at instant 0 :
# (5, 100, 1000) -> 0.0
# ------------------
# Evaluation of NEXT((p0 >= 0.5)) at instant 0 :
# (6, 100, 1000) -> 0.0
# ------------------
# Evaluation of NEXT((p0 >= 0.5)) at instant 0 :
# (7, 100, 1000) -> 0.0
# ------------------
# Evaluation of NEXT((p0 >= 0.5)) at instant 0 :
# (8, 100, 1000) -> 0.0
# ------------------
# Evaluation of NEXT((p0 >= 0.5)) at instant 0 :
# (9, 100, 1000) -> 0.0
# SLICING TIME 0.0
# PARSING TIME 0.0
# ------------------
# Evaluation of WEAK_NEXT((p0 >= 0.5)) at instant 0 :
# (0, 100, 1000) -> 0.0
# ------------------
# Evaluation of WEAK_NEXT((p0 >= 0.5)) at instant 0 :
# (1, 100, 1000) -> 0.0
# ------------------
# Evaluation of WEAK_NEXT((p0 >= 0.5)) at instant 0 :
# (2, 100, 1000) -> 0.0
# ------------------
# Evaluation of WEAK_NEXT((p0 >= 0.5)) at instant 0 :
# (3, 100, 1000) -> 0.0
# ------------------
# Evaluation of WEAK_NEXT((p0 >= 0.5)) at instant 0 :
# (4, 100, 1000) -> 0.0
# ------------------
# Evaluation of WEAK_NEXT((p0 >= 0.5)) at instant 0 :
# (5, 100, 1000) -> 0.0
# ------------------
# Evaluation of WEAK_NEXT((p0 >= 0.5)) at instant 0 :
# (6, 100, 1000) -> 0.0
# ------------------
# Evaluation of WEAK_NEXT((p0 >= 0.5)) at instant 0 :
# (7, 100, 1000) -> 0.0
# ------------------
# Evaluation of WEAK_NEXT((p0 >= 0.5)) at instant 0 :
# (8, 100, 1000) -> 0.0
# ------------------
# Evaluation of WEAK_NEXT((p0 >= 0.5)) at instant 0 :
# (9, 100, 1000) -> 0.0
# SLICING TIME 0.0
# PARSING TIME 0.016452550888061523
# ------------------
# Evaluation of ALWAYS((p0 >= 0.5)) at instant 0 :
# (0, 100, 1000) -> 0.03624391555786133
# ------------------
# Evaluation of ALWAYS((p0 >= 0.5)) at instant 0 :
# (1, 100, 1000) -> 0.03125953674316406
# ------------------
# Evaluation of ALWAYS((p0 >= 0.5)) at instant 0 :
# (2, 100, 1000) -> 0.04687333106994629
# ------------------
# Evaluation of ALWAYS((p0 >= 0.5)) at instant 0 :
# (3, 100, 1000) -> 0.03125357627868652
# ------------------
# Evaluation of ALWAYS((p0 >= 0.5)) at instant 0 :
# (4, 100, 1000) -> 0.06250500679016113
# ------------------
# Evaluation of ALWAYS((p0 >= 0.5)) at instant 0 :
# (5, 100, 1000) -> 0.08510708808898926
# ------------------
# Evaluation of ALWAYS((p0 >= 0.5)) at instant 0 :
# (6, 100, 1000) -> 0.06128048896789551
# ------------------
# Evaluation of ALWAYS((p0 >= 0.5)) at instant 0 :
# (7, 100, 1000) -> 0.06456971168518066
# ------------------
# Evaluation of ALWAYS((p0 >= 0.5)) at instant 0 :
# (8, 100, 1000) -> 0.09858560562133789
# ------------------
# Evaluation of ALWAYS((p0 >= 0.5)) at instant 0 :
# (9, 100, 1000) -> 0.10247516632080078
# SLICING TIME 0.0
# PARSING TIME 0.0
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (0, 100, 1000) -> 0.08368301391601562
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (1, 100, 1000) -> 0.12126350402832031
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (2, 100, 1000) -> 0.06004738807678223
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (3, 100, 1000) -> 0.048269033432006836
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (4, 100, 1000) -> 0.2985529899597168
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (5, 100, 1000) -> 0.04687380790710449
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (6, 100, 1000) -> 0.0468754768371582
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (7, 100, 1000) -> 0.07450628280639648
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (8, 100, 1000) -> 0.04889106750488281
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (9, 100, 1000) -> 0.33600616455078125
# SLICING TIME 0.0
# PARSING TIME 0.0010027885437011719
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (0, 100, 1000) -> 0.10857081413269043
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (1, 100, 1000) -> 0.062499046325683594
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (2, 100, 1000) -> 0.07982659339904785
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (3, 100, 1000) -> 0.059953927993774414
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (4, 100, 1000) -> 0.09373617172241211
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (5, 100, 1000) -> 0.057549476623535156
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (6, 100, 1000) -> 0.25539088249206543
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (7, 100, 1000) -> 0.04687333106994629
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (8, 100, 1000) -> 0.04687833786010742
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (9, 100, 1000) -> 0.062497854232788086
# SLICING TIME 0.0
# PARSING TIME 0.0
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (0, 100, 1000) -> 0.0625007152557373
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (1, 100, 1000) -> 0.0578920841217041
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (2, 100, 1000) -> 0.046869516372680664
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (3, 100, 1000) -> 0.0624995231628418
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (4, 100, 1000) -> 0.0468754768371582
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (5, 100, 1000) -> 0.0625009536743164
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (6, 100, 1000) -> 0.0625002384185791
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (7, 100, 1000) -> 0.04687380790710449
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (8, 100, 1000) -> 0.09375119209289551
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (9, 100, 1000) -> 0.06319737434387207
# SLICING TIME 0.0
# PARSING TIME 0.0
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (0, 100, 1000) -> 0.05267333984375
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (1, 100, 1000) -> 0.062499284744262695
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (2, 100, 1000) -> 0.06516075134277344
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (3, 100, 1000) -> 0.06255173683166504
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (4, 100, 1000) -> 0.05292034149169922
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (5, 100, 1000) -> 0.062499046325683594
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (6, 100, 1000) -> 0.0625009536743164
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (7, 100, 1000) -> 0.062499046325683594
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (8, 100, 1000) -> 0.05140829086303711
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (9, 100, 1000) -> 0.06250429153442383
# SLICING TIME 0.0
# PARSING TIME 0.0
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (0, 100, 1000) -> 0.06250333786010742
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (1, 100, 1000) -> 0.046872615814208984
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (2, 100, 1000) -> 0.06249880790710449
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
#
# ------------------
# Evaluation of ALWAYS((p0 >= 0.5)) at instant 0 :
# (7, 100000, 2000) -> 23.490781784057617
# ------------------
# Evaluation of ALWAYS((p0 >= 0.5)) at instant 0 :
# (8, 100000, 2000) -> 25.238085985183716
# ------------------
# Evaluation of ALWAYS((p0 >= 0.5)) at instant 0 :
# (9, 100000, 2000) -> 28.817747831344604
# SLICING TIME 0.5058231353759766
# PARSING TIME 0.0
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (0, 100000, 2000) -> 24.15891146659851
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (1, 100000, 2000) -> 30.326996564865112
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (2, 100000, 2000) -> 26.54780673980713
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (3, 100000, 2000) -> 25.801649570465088
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (4, 100000, 2000) -> 28.34539031982422
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (5, 100000, 2000) -> 20.63575792312622
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (6, 100000, 2000) -> 23.057907819747925
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (7, 100000, 2000) -> 20.25170636177063
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (8, 100000, 2000) -> 27.21070909500122
# ------------------
# Evaluation of EVENTUALLY((p0 >= 0.5)) at instant 0 :
# (9, 100000, 2000) -> 22.707749605178833
# SLICING TIME 0.0
# PARSING TIME 0.0
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (0, 100000, 2000) -> 35.0851833820343
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (1, 100000, 2000) -> 40.44442915916443
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (2, 100000, 2000) -> 33.07109212875366
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (3, 100000, 2000) -> 32.306697607040405
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (4, 100000, 2000) -> 32.26977181434631
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (5, 100000, 2000) -> 32.39530301094055
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (6, 100000, 2000) -> 32.147404193878174
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (7, 100000, 2000) -> 32.144644260406494
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (8, 100000, 2000) -> 32.7634379863739
# ------------------
# Evaluation of ((p0 UNTIL p1) >= 0.5) at instant 0 :
# (9, 100000, 2000) -> 33.352099895477295
# SLICING TIME 0.0
# PARSING TIME 0.0
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (0, 100000, 2000) -> 32.179707765579224
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (1, 100000, 2000) -> 32.8981671333313
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (2, 100000, 2000) -> 34.42782020568848
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (3, 100000, 2000) -> 41.67968130111694
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (4, 100000, 2000) -> 32.71185040473938
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (5, 100000, 2000) -> 32.31922745704651
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (6, 100000, 2000) -> 32.352569580078125
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (7, 100000, 2000) -> 31.90466856956482
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (8, 100000, 2000) -> 32.95651626586914
# ------------------
# Evaluation of ((p0 WEAK_UNTIL p1) >= 0.5) at instant 0 :
# (9, 100000, 2000) -> 33.18140387535095
# SLICING TIME 0.0
# PARSING TIME 0.0
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (0, 100000, 2000) -> 32.782644510269165
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (1, 100000, 2000) -> 32.43994379043579
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (2, 100000, 2000) -> 34.204184770584106
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (3, 100000, 2000) -> 33.461710929870605
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (4, 100000, 2000) -> 33.614542722702026
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (5, 100000, 2000) -> 32.35477375984192
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (6, 100000, 2000) -> 33.47003221511841
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (7, 100000, 2000) -> 37.373000144958496
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (8, 100000, 2000) -> 33.39924621582031
# ------------------
# Evaluation of ((p0 RELEASE p1) >= 0.5) at instant 0 :
# (9, 100000, 2000) -> 33.373305797576904
# SLICING TIME 0.0
# PARSING TIME 0.01562643051147461
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (0, 100000, 2000) -> 33.81427574157715
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (1, 100000, 2000) -> 32.90198731422424
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (2, 100000, 2000) -> 34.35972285270691
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (3, 100000, 2000) -> 35.246705770492554
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (4, 100000, 2000) -> 39.63709497451782
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (5, 100000, 2000) -> 43.608274936676025
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (6, 100000, 2000) -> 33.58645820617676
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (7, 100000, 2000) -> 33.73526883125305
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (8, 100000, 2000) -> 32.74902844429016
# ------------------
# Evaluation of ((p0 STRONG_RELEASE p1) >= 0.5) at instant 0 :
# (9, 100000, 2000) -> 57.530712842941284
# Results saved successfully.
